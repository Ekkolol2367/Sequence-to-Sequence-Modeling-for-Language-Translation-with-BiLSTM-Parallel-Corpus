# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Embedding, Bidirectional, Concatenate
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint

batch_size = 32
latent_dim = 128
num_samples = 40000
epochs = 50
validation_split = 0.2

# Load data
input_texts, target_texts = [], []
input_chars, target_chars = set(), set()

with open('./fra.txt', 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

for line in lines[:min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split('\t')
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    input_chars.update(input_text)
    target_chars.update(target_text)

input_chars = sorted(list(input_chars))
target_chars = sorted(list(target_chars))
num_encoder_tokens = len(input_chars)
num_decoder_tokens = len(target_chars)
max_encoder_seq_length = max(len(txt) for txt in input_texts)
max_decoder_seq_length = max(len(txt) for txt in target_texts)

print(f'Number of samples: {len(input_texts)}')
print(f'Number of unique input tokens: {num_encoder_tokens}')
print(f'Number of unique output tokens: {num_decoder_tokens}')
print(f'Max sequence length for inputs: {max_encoder_seq_length}')
print(f'Max sequence length for outputs: {max_decoder_seq_length}')

# Vectorize data
input_token_index = dict((char, i) for i, char in enumerate(input_chars))
target_token_index = dict((char, i) for i, char in enumerate(target_chars))

encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length), dtype='int32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length), dtype='int32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t] = input_token_index[char]
    for t, char in enumerate(target_text):
        decoder_input_data[i, t] = target_token_index[char]
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.

# Define the model
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(num_encoder_tokens, latent_dim)(encoder_inputs)
encoder_bi_lstm, forward_h, forward_c, backward_h, backward_c = Bidirectional(
    LSTM(latent_dim, return_state=True, return_sequences=False))(encoder_embedding)
state_h = Concatenate()([forward_h, backward_h])
state_c = Concatenate()([forward_c, backward_c])
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(num_decoder_tokens, latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim * 2, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Train the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['acc'])
early_stop = EarlyStopping(monitor='val_loss', patience=5)
checkpoint = ModelCheckpoint('model_weights.keras', monitor='val_loss', save_best_only=True)
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=validation_split,
        callbacks=[early_stop, checkpoint])

# Define encoder and decoder models for inference
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim * 2,))
decoder_state_input_c = Input(shape=(latent_dim * 2,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(decoder_embedding, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# Reverse token index dictionaries
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())

# Decode sequence
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = target_token_index['\t']

    decoded_sentence = ''
    stop_condition = False
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        if sampled_char == '\n' or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        states_value = [h, c]

    return decoded_sentence

# Test the model
input_sentences = []
decoded_sentences = []
separator_lines = []
french_to_english_output = []
english_to_french_output = []

for seq_index in range(10, 1000, 10):
    input_seq = encoder_input_data[seq_index:seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    
    input_sentences.append(input_texts[seq_index])
    decoded_sentences.append(decoded_sentence)
    separator_lines.append('-')

    # Store outputs for both directions
    french_to_english_output.append((input_texts[seq_index], decoded_sentence))
    english_to_french_output.append((decoded_sentence, input_texts[seq_index]))

# %%
print("\nFrench to English Translations:")
for input_sent, decoded_sent in french_to_english_output:
    print(f'French: {decoded_sent} -> English: {input_sent}')

# Print English to French outputs
print("\nEnglish to French Translations:")
for decoded_sent, input_sent in english_to_french_output:
    print(f'English: {input_sent} -> French: {decoded_sent}')
# Out:
# French to English Translations:
# French: Attendez !
#  -> English: Wait!
# French: Arrant.
#  -> English: Cheers!
# French: Atrefais.
#  -> English: Hop in.
# French: Je suis de moi.
#  -> English: I'm OK.
# French: Pars de moi.
#  -> English: No way!
# French: Demande de moi.
#  -> English: Ask Tom.
# French: Sois autresse.
#  -> English: Be fair.
# French: Appelle-moi.
#  -> English: Call me.
# French: Venez.
#  -> English: Come on.
# French: Sortes.
#  -> English: Get out.
# French: Va fais.
#  -> English: Go away.
# French: Il mais.
#  -> English: He runs.
# French: J'ai en chais.
#  -> English: I tried.
# French: Je suis tout.
#  -> English: I'm sad.
# French: Sais-toi !
#  -> English: Kiss me.
# French: Fermez-le.
#  -> English: Shut up!
# French: Réveillez-vous !
#  -> English: Wake up!
# French: Nous avons dépourdis.
#  -> English: We lost.
# French: Suis-je maintent ?
#  -> English: Am I fat?
# French: Sois conticieux.
#  -> English: Be still.
# French: Dis-nous !
#  -> English: Drive on.
# French: Sortiez !
#  -> English: Get real!
# French: Passez le problesse.
#  -> English: Have fun.
# French: Comme ce manche.
#  -> English: How nice!
# French: Je l'ai fait.
#  -> English: I did it.
# French: Je l'ai vue.
#  -> English: I saw it.
# French: Je suis sauvé.
#  -> English: I'm back.
# French: Je suis tout.
#  -> English: I'm fast.
# French: Je suis vition.
#  -> English: I'm home.
# French: Je suis tout.
#  -> English: I'm sure.
# French: Je suis saus.
#  -> English: I'm weak.
# French: C'est contre.
#  -> English: It's new.
# French: Allons de moi.
#  -> English: Let's go!
# French: Elle est parti.
#  -> English: She died.
# French: Chontez.
#  -> English: Terrific!
# French: Tom parti.
#  -> English: Tom left.
# French: Elle chattes.
#  -> English: Use this.
# French: Nous sommes de moi.
#  -> English: We agree.
# French: Tu chanter.
#  -> English: After you.
# French: Appelle !
#  -> English: Calm down.
# French: Viens.
#  -> English: Come over!
# French: Ai-je fait cela ?
#  -> English: Did I win?
# French: Ne me tendez pas.
#  -> English: Don't run.
# French: Oublie !
#  -> English: Forget it!
# French: Sortiez pas.
#  -> English: Get ready.
# French: Attrape le mois.
#  -> English: Grab that.
# French: Il est suppé.
#  -> English: He's rich.
# French: Comment va vous ?
#  -> English: How's Tom?
# French: Je suis prête.
#  -> English: I am lazy.
# French: Je te dit.
#  -> English: I beg you.
# French: Je me suis amusé.
#  -> English: I had fun.
# French: Je me suis parti.
#  -> English: I mean it!
# French: J'ai besoin.
#  -> English: I need it.
# French: Je l'ai vue.
#  -> English: I saw him.
# French: Je vous ai vant.
#  -> English: I saw you.
# French: Je me suis désolée.
#  -> English: I woke up.
# French: Je parlerai.
#  -> English: I'll pack.
# French: Je suis un pouver.
#  -> English: I'm a cop.
# French: Je suis tout.
#  -> English: I'm blind.
# French: Je suis souri.
#  -> English: I'm early.
# French: Je suis sauvé.
#  -> English: I'm loyal.
# French: Je suis prêt.
#  -> English: I'm ready.
# French: Je suis sauché.
#  -> English: I'm tired.
# French: Est-ce désolée ?
#  -> English: Is it bad?
# French: Ça peux.
#  -> English: It stinks.
# French: C'est malade.
#  -> English: It's dead.
# French: C'est contie.
#  -> English: It's ours.
# French: Laisse-moi le faire.
#  -> English: Let me go!
# French: Allons de moi.
#  -> English: Let's ask.
# French: Laissez-vous le prine.
#  -> English: Loosen up.
# French: Parlez-vous ?
#  -> English: Pardon me?
# French: Elle a pris.
#  -> English: She cried.
# French: Reste des liche.
#  -> English: Stay back.
# French: Arrêtez !
#  -> English: Stop that.
# French: Prends le mois.
#  -> English: Take mine.
# French: Ils ont des pouver.
#  -> English: They lied.
# French: Tom parti.
#  -> English: Tom spoke.
# French: Attends de la parti.
#  -> English: Wait here.
# French: Nous l'avons part.
#  -> English: We saw it.
# French: Nous contrenter.
#  -> English: We'll win.
# French: Que sente de moi ?
#  -> English: What else?
# French: Qui est cela ?
#  -> English: Who is it?
# French: Vous avertie.
#  -> English: You idiot!
# French: Suis-je de la voiture ?
#  -> English: Am I dying?
# French: Suis-je de la voiture ?
#  -> English: Am I wrong?
# French: Êtes-vous en train de vous la maison.
#  -> English: Are you up?
# French: Soyez prête.
#  -> English: Be careful.
# French: Sois sécurité.
#  -> English: Be serious.
# French: Vérivez-vous.
#  -> English: Check this.
# French: Arrête !
#  -> English: Cut it out!
# French: Ne me parle pas.
#  -> English: Don't fret.
# French: Ne faites pas !
#  -> English: Don't wait.
# French: Sonte du toi.
#  -> English: Get a life!
# French: Il a contrarié.
#  -> English: He hung up.
# French: Il l'a fait de moi.
#  -> English: He made it.
# French: Voici.
#  -> English: Here it is.
# French: Je suis un proble.
#  -> English: I am a man.
# French: Je l'ai détendue.
#  -> English: I built it.
# French: Je peux le faire.
#  -> English: I can wait.
#
# English to French Translations:
# English: Wait! -> French: Attendez !
#
# English: Cheers! -> French: Arrant.
#
# English: Hop in. -> French: Atrefais.
#
# English: I'm OK. -> French: Je suis de moi.
#
# English: No way! -> French: Pars de moi.
#
# English: Ask Tom. -> French: Demande de moi.
#
# English: Be fair. -> French: Sois autresse.
#
# English: Call me. -> French: Appelle-moi.
#
# English: Come on. -> French: Venez.
#
# English: Get out. -> French: Sortes.
#
# English: Go away. -> French: Va fais.
#
# English: He runs. -> French: Il mais.
#
# English: I tried. -> French: J'ai en chais.
#
# English: I'm sad. -> French: Je suis tout.
#
# English: Kiss me. -> French: Sais-toi !
#
# English: Shut up! -> French: Fermez-le.
#
# English: Wake up! -> French: Réveillez-vous !
#
# English: We lost. -> French: Nous avons dépourdis.
#
# English: Am I fat? -> French: Suis-je maintent ?
#
# English: Be still. -> French: Sois conticieux.
#
# English: Drive on. -> French: Dis-nous !
#
# English: Get real! -> French: Sortiez !
#
# English: Have fun. -> French: Passez le problesse.
#
# English: How nice! -> French: Comme ce manche.
#
# English: I did it. -> French: Je l'ai fait.
#
# English: I saw it. -> French: Je l'ai vue.
#
# English: I'm back. -> French: Je suis sauvé.
#
# English: I'm fast. -> French: Je suis tout.
#
# English: I'm home. -> French: Je suis vition.
#
# English: I'm sure. -> French: Je suis tout.
#
# English: I'm weak. -> French: Je suis saus.
#
# English: It's new. -> French: C'est contre.
#
# English: Let's go! -> French: Allons de moi.
#
# English: She died. -> French: Elle est parti.
#
# English: Terrific! -> French: Chontez.
#
# English: Tom left. -> French: Tom parti.
#
# English: Use this. -> French: Elle chattes.
#
# English: We agree. -> French: Nous sommes de moi.
#
# English: After you. -> French: Tu chanter.
#
# English: Calm down. -> French: Appelle !
#
# English: Come over! -> French: Viens.
#
# English: Did I win? -> French: Ai-je fait cela ?
#
# English: Don't run. -> French: Ne me tendez pas.
#
# English: Forget it! -> French: Oublie !
#
# English: Get ready. -> French: Sortiez pas.
#
# English: Grab that. -> French: Attrape le mois.
#
# English: He's rich. -> French: Il est suppé.
#
# English: How's Tom? -> French: Comment va vous ?
#
# English: I am lazy. -> French: Je suis prête.
#
# English: I beg you. -> French: Je te dit.
#
# English: I had fun. -> French: Je me suis amusé.
#
# English: I mean it! -> French: Je me suis parti.
#
# English: I need it. -> French: J'ai besoin.
#
# English: I saw him. -> French: Je l'ai vue.
#
# English: I saw you. -> French: Je vous ai vant.
#
# English: I woke up. -> French: Je me suis désolée.
#
# English: I'll pack. -> French: Je parlerai.
#
# English: I'm a cop. -> French: Je suis un pouver.
#
# English: I'm blind. -> French: Je suis tout.
#
# English: I'm early. -> French: Je suis souri.
#
# English: I'm loyal. -> French: Je suis sauvé.
#
# English: I'm ready. -> French: Je suis prêt.
#
# English: I'm tired. -> French: Je suis sauché.
#
# English: Is it bad? -> French: Est-ce désolée ?
#
# English: It stinks. -> French: Ça peux.
#
# English: It's dead. -> French: C'est malade.
#
# English: It's ours. -> French: C'est contie.
#
# English: Let me go! -> French: Laisse-moi le faire.
#
# English: Let's ask. -> French: Allons de moi.
#
# English: Loosen up. -> French: Laissez-vous le prine.
#
# English: Pardon me? -> French: Parlez-vous ?
#
# English: She cried. -> French: Elle a pris.
#
# English: Stay back. -> French: Reste des liche.
#
# English: Stop that. -> French: Arrêtez !
#
# English: Take mine. -> French: Prends le mois.
#
# English: They lied. -> French: Ils ont des pouver.
#
# English: Tom spoke. -> French: Tom parti.
#
# English: Wait here. -> French: Attends de la parti.
#
# English: We saw it. -> French: Nous l'avons part.
#
# English: We'll win. -> French: Nous contrenter.
#
# English: What else? -> French: Que sente de moi ?
#
# English: Who is it? -> French: Qui est cela ?
#
# English: You idiot! -> French: Vous avertie.
#
# English: Am I dying? -> French: Suis-je de la voiture ?
#
# English: Am I wrong? -> French: Suis-je de la voiture ?
#
# English: Are you up? -> French: Êtes-vous en train de vous la maison.
#
# English: Be careful. -> French: Soyez prête.
#
# English: Be serious. -> French: Sois sécurité.
#
# English: Check this. -> French: Vérivez-vous.
#
# English: Cut it out! -> French: Arrête !
#
# English: Don't fret. -> French: Ne me parle pas.
#
# English: Don't wait. -> French: Ne faites pas !
#
# English: Get a life! -> French: Sonte du toi.
#
# English: He hung up. -> French: Il a contrarié.
#
# English: He made it. -> French: Il l'a fait de moi.
#
# English: Here it is. -> French: Voici.
#
# English: I am a man. -> French: Je suis un proble.
#
# English: I built it. -> French: Je l'ai détendue.
#
# English: I can wait. -> French: Je peux le faire.
